# %% [markdown]
# ### Making API calls using the local ollama model ###

# %%
import os
import ollama
import logging
import time

logger = logging.getLogger(__name__)

# Import this module with autoreload
# %load_ext autoreload
# %autoreload 2
import agentix
from agentix.ollamamodel import Ollama as OllamaModel

print(f'Package version: {agentix.__version__}')
print(f'Authors: {agentix.__authors__}')
# Out:
# Package version: 0.0.1
# Authors: Andreas Werdich
# The Core for Computational Biomedicine at Harvard Medical School
# https://dbmi.hms.harvard.edu/about-dbmi/core-computational-biomedicine

# %%
# Let's check which models we have available
print(OllamaModel().list_models())

# Pull a model for demonstration
success = OllamaModel().pull_model(model_name='gemma3:latest')
print(success)
# Out:
# ['llama3.2:latest']
# gemma3:latest: 100%|█████████▉| 3.34G/3.34G [00:38<00:00, 87.7MB/s, success]
# True

# %%
# Run a simple prompt
system_prompt = 'You are a powerful AI system.'
user_prompt = 'Explain in a short paragraph how a transformer-based language model works.'

# Package messages
messages = OllamaModel.create_messages(system_prompt=system_prompt, user_prompt=user_prompt)
display(*messages)

# Send messages to model
model_name = 'gemma3:latest'
temperature = 0.7
client = OllamaModel().create_client()
response = client.chat(model=model_name,
                       messages=messages,
                       options={'temperature': temperature})
print()
print(response.message.content)
# Out:
# {'role': 'system', 'content': 'You are a powerful AI system.'}
# {'role': 'user',
#  'content': 'Explain in a short paragraph how a transformer-based language model works.'}
# Okay, here’s a concise explanation of how transformer-based language models work:
#
# At their core, transformers rely on a mechanism called “attention.” Instead of processing words sequentially like older models, they look at *all* the words in a sentence simultaneously to understand relationships between them. This "attention" layer assigns weights based on how relevant each word is to every other word – essentially figuring out which words are most important for understanding context.  These attention scores are then used to predict the next word in a sequence, building upon previous predictions and constantly refining its understanding of the text through multiple layers of this process. Essentially, they learn intricate patterns within language by focusing on connections rather than just linear order.

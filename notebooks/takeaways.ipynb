# %% [markdown]
# ### Some important notes from the course ###

# %%
import sys
import os
from dotenv import load_dotenv

# The old API version
from openai import AzureOpenAI

# The new API version
from openai import OpenAI

# %load_ext autoreload
# %autoreload 2
import agentix

print(f'Package version: {agentix.__version__}')
print(f'Authors:         {agentix.__authors__}')
print(f'Python version:  {sys.version}')
# Out:
# Package version: 0.0.1
# Authors:         Andreas Werdich
# The Core for Computational Biomedicine at Harvard Medical School
# https://dbmi.hms.harvard.edu/about-dbmi/core-computational-biomedicine
# Python version:  3.12.13 (main, Jul 14 2026, 02:09:00) [GCC 14.2.0]

# %%
# Load environmental variables
load_dotenv()
data_root = os.environ.get('AZURE_API_KEY')
if data_root is None:
    print('Edit the "env"file and copy it to the root of the repository.')

# %%
api_key = os.environ['AZURE_API_KEY']
azure_endpoint = os.environ['AZURE_API_ENDPOINT']
print(f'AZURE ENDPOINT LOADED: {azure_endpoint}')
model = 'gpt-5-mini'
# Out:
# AZURE ENDPOINT LOADED: https://azure-ai.hms.edu

# %% [markdown]
# ### Azure OpenAI in Microsoft Foundry Models v1 API ###
# The v1 API simplifies authentication, removes the need for dated api-version parameters, and supports cross-provider model calls.

# %%
base_url = f'{azure_endpoint}/openai/v1'

message = [
    {"role": "system", "content": "You are a helpful AI assistant."},
    {"role": "user", "content": "Write a one-sentence poem about unicorns"}
]

client = OpenAI(base_url=base_url, api_key=api_key, default_headers={'api-key': api_key})

response = client.chat.completions.create(model=model,
                                          messages=message,
                                          temperature=1.0,
                                          max_completion_tokens=500)
print('Response')
print()
print(response.choices[0].message.content)
print()
print(f'finish_reason: {response.choices[0].finish_reason}')   # likely "length"
print()
usage = response.usage
print(usage.model_dump_json(indent=2))
# Out:
# Response
#
# Under the hush of moonlit pines, a solitary unicorn breathes constellations into the night and forgets its shadow.
#
# finish_reason: stop
#
# {
#   "completion_tokens": 100,
#   "prompt_tokens": 26,
#   "total_tokens": 126,
#   "completion_tokens_details": {
#     "accepted_prediction_tokens": 0,
#     "audio_tokens": 0,
#     "reasoning_tokens": 64,
#     "rejected_prediction_tokens": 0
#   },
#   "prompt_tokens_details": {
#     "audio_tokens": 0,
#     "cache_write_tokens": null,
#     "cached_tokens": 0
#   },
#   "latency_checkpoint": {
#     "engine_tbt_ms": 7,
#     "engine_ttft_ms": 30,
#     "engine_ttlt_ms": 1014,
#     "pre_inference_ms": 149,
#     "service_tbt_ms": 7,
#     "service_ttft_ms": 379,
#     "service_ttlt_ms": 1355,
#     "total_duration_ms": 1216,
#     "user_visible_ttft_ms": 231
#   }
# }

# %% [markdown]
# ### 3 Definitions of an AI agent ###

# %% [markdown]
# ### Sam Altman ###
# "AI systems that can do work for you independently"
#
# ### Early 2025 consensus (Athropic, Hugging Face, ...) ###
# "AI systems where an LLM controls the workflow"
#
# ### Current prevailing view ###
# "An LLM with tools in a loop to achieve a goal"

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
import os
import sys

from openai import OpenAI

from IPython.display import Markdown, display

# %load_ext autoreload
# %autoreload 2
import agentix
from agentix.hmsmodel import get_access_token, HMSModel

print(f'Package version: {agentix.__version__}')
print(f'Authors:         {agentix.__authors__}')
print(f'Python version:  {sys.version}')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Package version: 0.0.1
# Authors:         Andreas Werdich
# The Core for Computational Biomedicine at Harvard Medical School
# https://dbmi.hms.harvard.edu/about-dbmi/core-computational-biomedicine
# Python version:  3.12.13 (main, Aug  5 2026, 01:10:24) [GCC 14.2.0]

# %%
# Get the access token
endpoint = os.environ['HMS_API_ENDPOINT']
hms_user = os.environ['HMS_USER']
hms_pass = os.environ['HMS_PASS']

hms_ai_token = get_access_token(username=hms_user, password=hms_pass)
base_url = f'{os.environ['HMS_API_ENDPOINT']}/v1'

# %%
# Create the model object
hms = HMSModel(token=hms_ai_token, model=None)
print(hms.model)

# Create the openai object
openai = OpenAI(base_url=base_url, api_key=hms_ai_token)
# Out:
# muse-glimmer

# %%
# First, ask for a business area
request = "Please propose a business area that might be worth exploring for an Agentic AI opportunity."
messages = [{"role": "user", "content": request}]
response = openai.chat.completions.create(model=hms.model, messages=messages)
response_content = response.choices[0].message.content
display(Markdown(response_content))
# Out:
# The most immediate agentic AI opportunity is **autonomous back-office operations for small-to-mid size professional services, specifically Healthcare Revenue Cycle Management for independent practices.**
#
# It is a perfect agentic fit because the work is multi-step, multi-system, highly regulated, repetitive, and currently done by humans on hold with phones and PDFs.
#
# ### The Business Area
#
# Independent dental, primary care, and specialty clinics with 1-20 providers. ~200k+ practices in the US alone. They all run the same painful revenue cycle: verify insurance, obtain prior auth, schedule, check-in, code, bill, chase denials, follow up on patient balances.
#
# TAM: US RCM market is $12B+ and growing. Independent practices spend 8-12% of revenue on RCM and still see 15-25% denial rates and 40-60 day AR days.
#
# ### Why Agentic AI now, not just LLM
#
# This is not Q&A. It's a closed-loop workflow with tools, memory and handoffs:
#
# ...
